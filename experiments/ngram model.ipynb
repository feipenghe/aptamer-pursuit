# %%
import os, sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
experiment_file = "ngram.json"
with open(experiment_file, 'r') as f:
    data = json.load(f)
    
print(str(data))
# Out:
# {'2': [[100, 117.78025571351388, 250.93140455560555], [200, 94.875259368618, 260.5068034109469], [300, 82.62415595063378, 258.4024663431275], [400, 74.52881956962155, 261.6540918492946], [500, 69.23492860777073, 267.7763177298333], [600, 65.41634472531497, 270.98594931724284], [700, 61.92966409152516, 272.85499041032665], [800, 59.683038174626766, 277.40728710581647], [900, 57.68271446876005, 277.10036440645644]], '3': [[100, 137.01522333872754, 254.40399200012536], [200, 113.2919938035351, 250.7200699391396], [300, 98.15167284798298, 249.1901570531919], [400, 87.3657860438491, 250.81174320677434], [500, 78.59119605637913, 249.82712534308948], [600, 71.94769077987463, 250.57193968085676], [700, 65.94997430485874, 249.33699939782588], [800, 60.79828749355854, 248.93909277357002], [900, 56.75808277493016, 252.1337610895604]], '4': [[100, 143.1646361474182, 256.2367465833517], [200, 119.9098065122361, 250.54209379286831], [300, 106.25293863127172, 247.67663936631976], [400, 95.52431099331251, 249.71064359079477], [500, 88.65860659514996, 247.85991929637282], [600, 81.31581989236454, 247.8748262136151], [700, 75.89330755903963, 247.74840664854253], [800, 71.28049496779784, 247.79891200012273], [900, 67.34338460800168, 246.4364242351443]], '5': [[100, 145.2879202593722, 255.09005928598597], [200, 122.77044981357187, 256.0579376780414], [300, 109.29088326470709, 252.26641247092968], [400, 98.26889491242217, 248.42548082038877], [500, 90.6314583322894, 249.8624785914367], [600, 84.58921957661882, 251.03360985346353], [700, 78.6919437491283, 248.19124114953584], [800, 73.41168340086031, 250.22011564765063], [900, 69.85310216790766, 248.1149886768197]], '6': [[100, 149.3845396717818, 258.504663957207], [200, 126.2506323789856, 253.9319583886257], [300, 111.60764665519594, 253.34606708944077], [400, 101.12111959551332, 254.47383534192858], [500, 92.97479953901549, 252.50235692566352], [600, 85.79264486417793, 252.4582544564517], [700, 80.25995625828931, 253.04223390952117], [800, 75.6069280064198, 250.32295126774665], [900, 71.49865080023663, 251.873519824168]]}

# %%
# Visualizations for a Lasso Linear Regression Model
varying_k = list(data.keys())

hundred_features = []
two_hundred_features = []
three_hundred_features = []
four_hundred_features = []
five_hundred_features = []
six_hundred_features = []
seven_hundred_features = []
eight_hundred_features = []
nine_hundred_features = []

for k in data.keys():
    vals = data[k]
    for v in vals:
        if v[0] == 100:
            hundred_features.append(v[2])
        elif v[0] == 200:
            two_hundred_features.append(v[2])
        elif v[0] == 300:
            three_hundred_features.append(v[2])
        elif v[0] == 400:
            four_hundred_features.append(v[2])
        elif v[0] == 500:
            five_hundred_features.append(v[2])
        elif v[0] == 600:
            six_hundred_features.append(v[2])
        elif v[0] == 700:
            seven_hundred_features.append(v[2])
        elif v[0] == 800:
            eight_hundred_features.append(v[2])
        else:
            nine_hundred_features.append(v[2])

plt.title("Test Set MSE Loss across different ngram hyperparameters")
plt.xlabel("K value")
plt.ylabel("Sum of MSE across all alleles")
plt.plot(varying_k, hundred_features, label="100 features")
plt.plot(varying_k, two_hundred_features, label="200 features")
plt.plot(varying_k, three_hundred_features, label="300 features")
plt.plot(varying_k, four_hundred_features, label="400 features")
plt.plot(varying_k, five_hundred_features, label="500 features")
plt.plot(varying_k, six_hundred_features, label="600 features")
plt.plot(varying_k, seven_hundred_features, label="700 features")
plt.plot(varying_k, eight_hundred_features, label="800 features")
plt.plot(varying_k, nine_hundred_features, label="900 features")
plt.legend()
plt.show()

# %%
# Visualizations for a Lasso Linear Regression Model
varying_k = list(data.keys())

hundred_features = []
two_hundred_features = []
three_hundred_features = []
four_hundred_features = []
five_hundred_features = []
six_hundred_features = []
seven_hundred_features = []
eight_hundred_features = []
nine_hundred_features = []

for k in data.keys():
    vals = data[k]
    for v in vals:
        if v[0] == 100:
            hundred_features.append(v[1])
        elif v[0] == 200:
            two_hundred_features.append(v[1])
        elif v[0] == 300:
            three_hundred_features.append(v[1])
        elif v[0] == 400:
            four_hundred_features.append(v[1])
        elif v[0] == 500:
            five_hundred_features.append(v[1])
        elif v[0] == 600:
            six_hundred_features.append(v[1])
        elif v[0] == 700:
            seven_hundred_features.append(v[1])
        elif v[0] == 800:
            eight_hundred_features.append(v[1])
        else:
            nine_hundred_features.append(v[1])

plt.title("Training Set MSE Loss across different ngram hyperparameters")
plt.xlabel("K value")
plt.ylabel("Sum of MSE across all alleles")
plt.plot(varying_k, hundred_features, label="100 features")
plt.plot(varying_k, two_hundred_features, label="200 features")
plt.plot(varying_k, three_hundred_features, label="300 features")
plt.plot(varying_k, four_hundred_features, label="400 features")
plt.plot(varying_k, five_hundred_features, label="500 features")
plt.plot(varying_k, six_hundred_features, label="600 features")
plt.plot(varying_k, seven_hundred_features, label="700 features")
plt.plot(varying_k, eight_hundred_features, label="800 features")
plt.plot(varying_k, nine_hundred_features, label="900 features")
plt.legend()
plt.show()
