# %%
import os, sys
import seaborn as sns
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Varying the number of features (d)

# %% [markdown]
# ### With a constant learning rate of 0.01

# %%
d_values = [1000, 1400, 1500, 1800, 2000, 2200, 2600, 3000, 3400]
accuracies = [28, 20, 24, 28, 26, 26, 19, 25, 24]

plt.title("Accuracy in predicting affinity class while varying #features")
plt.xlabel("# features")
plt.ylabel("Accuracy")

plt.plot(d_values, accuracies)

# %%
## Varying the k_values
